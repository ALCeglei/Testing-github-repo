# %%
import pandas as pd

df = pd.read_csv('Pokemon.csv')
top = df.head(10)
bott = df.tail(10)

top
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# print(df.iloc[0:6])
# print('-----')
# print(df.iloc[5, 1])
# for index, row in df.iterrows():
#     print(index, row)

withFire = df.loc[df['Type 1'] == 'Fire']
print(withFire)

# df.sort_values('Name', ascending=True)
# Out:
#        #                       Name Type 1  S+HP
# 4      4                 Charmander   Fire   208
# 5      5                 Charmeleon   Fire   266
# 6      6                  Charizard   Fire   346
# 7      6  CharizardMega Charizard X   Fire   438
# 8      6  CharizardMega Charizard Y   Fire   386
# 42    37                     Vulpix   Fire   185
# 43    38                  Ninetales   Fire   325
# 63    58                  Growlithe   Fire   255
# 64    59                   Arcanine   Fire   405
# 83    77                     Ponyta   Fire   310
# 84    78                   Rapidash   Fire   370
# 135  126                     Magmar   Fire   348
# 147  136                    Flareon   Fire   390
# 158  146                    Moltres   Fire   380
# 169  155                  Cyndaquil   Fire   208
# 170  156                    Quilava   Fire   266
# 171  157                 Typhlosion   Fire   346
# 236  218                     Slugma   Fire   140
# ...

# %%
# df['S+HP'] = df['Speed'] + df['HP']

# df = df.drop(columns=['S+HP'])

df['S+HP'] = df.iloc[:, [5, 10]].sum(axis=1)

cols = list(df.columns.values)

df = df[cols[0:3] + cols[4:-3] + [cols[-1]]]

df.head(6)
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
# 5  5             Charmeleon   Fire    405  58      64       58       80
#
#    Sp. Def  Speed  S+HP
# 0       65     45    90
# 1       80     60   120
# 2      100     80   160
# 3      120     80   160
# 4       50     65   104
# 5       65     80   138

# %%
df.to_excel('other.xlsx', index=False)

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Attack'] == 100)]   # and= &    or= |
# Out:
#        #                   Name    Type 1  Attack  S+HP
# 0      1              Bulbasaur     Grass      49   139
# 1      2                Ivysaur     Grass      62   182
# 2      3               Venusaur     Grass      82   242
# 3      3  VenusaurMega Venusaur     Grass     100   260
# 33    28              Sandslash    Ground     100   240
# 48    43                 Oddish     Grass      50   125
# 49    44                  Gloom     Grass      65   165
# 50    45              Vileplume     Grass      80   205
# 73    67                Machoke  Fighting     100   225
# 75    69             Bellsprout     Grass      75   165
# 76    70             Weepinbell     Grass      90   210
# 77    71             Victreebel     Grass     105   255
# 84    78               Rapidash      Fire     100   270
# 110  102              Exeggcute     Grass      40   140
# 111  103              Exeggutor     Grass      95   245
# 122  114                Tangela     Grass      55   180
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]  #   ~ it means "anti"
# Out:
#        #                   Name    Type 1  Attack  S+HP
# 0      1              Bulbasaur     Grass      49   139
# 1      2                Ivysaur     Grass      62   182
# 2      3               Venusaur     Grass      82   242
# 4      4             Charmander      Fire      52   156
# 5      5             Charmeleon      Fire      64   202
# 6      6              Charizard      Fire      84   262
# 9      7               Squirtle     Water      48   135
# 10     8              Wartortle     Water      63   180
# 11     9              Blastoise     Water      83   240
# 13    10               Caterpie       Bug      30   120
# 14    11                Metapod       Bug      20   100
# 15    12             Butterfree       Bug      45   175
# 16    13                 Weedle       Bug      35   125
# 17    14                 Kakuna       Bug      25   105
# 18    15               Beedrill       Bug      90   230
# 20    16                 Pidgey    Normal      45   141
# ...

# %%
df.loc[df['Type 1'] == 'Flamer', "Attack"] = df['Attack'] + 10
df.sort_values('Name')
# Out:
#        #                       Name    Type 1  Attack  S+HP
# 510  460                  Abomasnow     Grass      92   242
# 511  460    AbomasnowMega Abomasnow     Grass     132   252
# 68    63                       Abra   Psychic      20   135
# 392  359                      Absol      Dark     130   270
# 393  359            AbsolMega Absol      Dark     150   330
# 678  617                   Accelgor       Bug      70   295
# 750  681       AegislashBlade Forme     Steel     150   270
# 751  681      AegislashShield Forme     Steel      50   170
# 153  142                 Aerodactyl      Rock     105   315
# 154  142  AerodactylMega Aerodactyl      Rock     135   365
# 332  306                     Aggron     Steel     110   230
# 333  306          AggronMega Aggron     Steel     140   260
# 205  190                      Aipom    Normal      70   210
# 70    65                   Alakazam   Psychic      50   225
# 71    65      AlakazamMega Alakazam   Psychic      50   255
# ...

# %%
grouped = df.groupby('Type 1').mean()

grouped.sort_values('Type 1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-147191413b54> in <module>
# ----> 1 grouped = df.groupby('Type 1').mean()
#       2
#       3 grouped.sort_values('Type 1')
#
# NameError: name 'df' is not defined

# %%
df['count'] = 1

df.groupby('Type 1').count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64
